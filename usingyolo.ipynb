# %% [markdown]
# <a href="https://colab.research.google.com/github/harshdharmik29/object-detection-using-yolo/blob/main/usingyolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install YOLO library
# !pip install ultralytics

# Import libraries
from ultralytics import YOLO
from google.colab import files
import cv2
import matplotlib.pyplot as plt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.8 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Step 2: Upload image from desktop
uploaded = files.upload()

# Get uploaded file name
image_path = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-4f7de1f0-6157-412a-98e7-da80df6411e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f7de1f0-6157-412a-98e7-da80df6411e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Step 3: Load pretrained YOLO model
model = YOLO("yolov8n.pt")

# Perform object detection
results = model(image_path)

# Plot detection results on image
annotated_img = results[0].plot()

# Convert BGR to RGB for display
annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(annotated_img_rgb)
plt.axis("off")
plt.show()
# Out:
# ...
#
# image 1/1 /content/images.webp: 640x640 3 elephants, 435.5ms
# Speed: 23.6ms preprocess, 435.5ms inference, 42.8ms postprocess per image at shape (1, 3, 640, 640)
